# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

bus_data = pd.read_csv("Data/bus_ridership_daily.csv", low_memory = False)

bus_data['date'] = pd.to_datetime(bus_data['date'], infer_datetime_format=True)
bus_data.head()
# Out:
#   route       date daytype  rides
# 0     3 2001-01-01       U   7354
# 1     4 2001-01-01       U   9288
# 2     6 2001-01-01       U   6048
# 3     8 2001-01-01       U   6309
# 4     9 2001-01-01       U  11207

# %%
bus_data.loc[(bus_data['date']>= "01-01-2018") & (bus_data['date']<= "01-27-2019")].groupby(pd.Grouper(key='date', freq='W')).agg({
    'rides': 'sum'
}).plot(kind = 'line', color='b')

plt.xlabel('Date')
plt.ylabel('Number of Bus Rides')
plt.title('Number of Bus Rides vs Date (2018-2019)')
# Out:
# Text(0.5, 1.0, 'Number of Bus Rides vs Date (2018-2019)')

# %%
bus_data.loc[(bus_data['date']>= "01-07-2019") & (bus_data['date']<= "01-26-2020")].groupby(pd.Grouper(key='date', freq='W')).agg({
    'rides': 'sum'
}).plot(kind = 'line', color='green')

plt.xlabel('Date')
plt.ylabel('Number of Bus Rides')
plt.title('Number of Bus Rides vs Date (2019-2020)')
# Out:
# Text(0.5, 1.0, 'Number of Bus Rides vs Date (2019-2020)')

# %%
bus_data.loc[(bus_data['date']>= "01-06-2020") & (bus_data['date']<= "01-31-2021")].groupby(pd.Grouper(key='date', freq='W')).agg({
    'rides': 'sum'
}).plot(kind = 'line', color='red')

plt.xlabel('Date')
plt.ylabel('Number of Bus Rides')
plt.title('Number of Bus Rides vs Date (2020)')
# Out:
# Text(0.5, 1.0, 'Number of Bus Rides vs Date (2020)')
